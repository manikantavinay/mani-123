# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Names=['Ramesh','Suresh','Sathish','Mahesh']
Age=[20,22,24,26]

# %% [markdown]
# **step-1:create a Dadaframe**

# %%
#pd.DataFrame(data,insex,columns,dtype,copy)
#pd.DataFrame(Names)
#pd.DataFrame(Names,'Names')
#pd.DataFrame(Names,columns='Names')
pd.DataFrame(Names,columns=['Names'])
# Out:
#      Names
# 0   Ramesh
# 1   Suresh
# 2  Sathish
# 3   Mahesh

# %%
pd.DataFrame(Names)
pd.DataFrame(Names,columns=['Names'])
pd.DataFrame(Names,index=['A','B','C','D'],columns=['Names'])
# Out:
#      Names
# A   Ramesh
# B   Suresh
# C  Sathish
# D   Mahesh

# %%
DATA=(Names,Age)
pd.DataFrame(DATA).T
# Out:
#          0   1
# 0   Ramesh  20
# 1   Suresh  22
# 2  Sathish  24
# 3   Mahesh  26

# %%
DATA=zip(Names,Age)
pd.DataFrame(DATA,columns=['Names','Age'])
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24
# 3   Mahesh   26

# %% [markdown]
# **step:-2 add a new column to already an existed df**

# %%
DATA=zip(Names,Age)
df=pd.DataFrame(DATA,columns=['Names','Age'])
df
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24
# 3   Mahesh   26

# %%
df[col_name ]#selection
        #updation
        #creationdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[col_name ]#selection
#       2         #updation
#       3         #creationdf
#
# NameError: name 'col_name' is not defined

# %%
df['Names']

# %%
df['Age']=[30,32,34,36]

# %%
df

# %%
df['city']=['hyd','pune','blr','Bihata']

# %%
df

# %% [markdown]
# - created a datafreme with one column
# - learned how to add a column names
# - learn how to change the index
# - create a dataframe with two coulmns using zip
# - understand how to select update and create  new column with already existed dataframe

# %%
import pandas as pd
Names=['hi','hii','hiiii']
Age=[20,20,20]
pd.DataFrame(Names)
# Out:
#        0
# 0     hi
# 1    hii
# 2  hiiii

# %%
df=pd.DataFrame(Names,columns=["Name"])
df
# Out:
#     Name
# 0     hi
# 1    hii
# 2  hiiii

# %%
data=zip(Names,Age)
d=pd.DataFrame(data,columns=["Names","Age"])
d
# Out:
#    Names  Age
# 0     hi   20
# 1    hii   20
# 2  hiiii   20

# %%
d['city']=['hyd','blr','mum']

# %%
d
# Out:
#    Names  Age city
# 0     hi   20  hyd
# 1    hii   20  blr
# 2  hiiii   20  mum

# %%
d['Age']=['30','30','30']

# %%
d
# Out:
#    Names Age city
# 0     hi  30  hyd
# 1    hii  30  blr
# 2  hiiii  30  mum

# %% [markdown]
# **sept-3 How add add to data to empty dataframe**

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['names']=['Ramesh','Suresh','Sathish']
df['age']=[20,22,24]
df['city']=['hyd','blr','chennai']

df
# Out:
#      names  age     city
# 0   Ramesh   20      hyd
# 1   Suresh   22      blr
# 2  Sathish   24  chennai

# %% [markdown]
# **step-4 create a dataframe using dictionary**

# %%
d={'Names':['Ramesh','Suresh','Sathish'],'Age':[20,22,24],'city':['hyd','mum','null']}

d
# Out:
# {'Names': ['Ramesh', 'Suresh', 'Sathish'],
#  'Age': [20, 22, 24],
#  'city': ['hyd', 'mum', 'null']}

# %%
df=pd.DataFrame(d)
df
# Out:
#      Names  Age  city
# 0   Ramesh   20   hyd
# 1   Suresh   22   mum
# 2  Sathish   24  null

# %% [markdown]
# **step=5 drop a new column**

# %%
d={'Names':['Ramesh','Suresh','Sathish'],'Age':[20,22,24],'city':['hyd','mum','null']}
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 d={'Names':['Ramesh','Suresh','Sathish'],'Age':[20,22,24],'city':['hyd','mum','null']}
# ----> 2 df
#
# NameError: name 'df' is not defined

# %%
df.drop(Lables,axis=0,index,columns,inplace=True)
# Out:
#   Cell In[6], line 1
#     df.drop(Lables,axis=0,index,columns,inplace=True)
#                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
df.drop(lables,axis)
df.drop('city',axis=0)#index drop eror
df.drop('city',axis=1)#clumn drop

df.drop(coiumns=['city'])
df.frop(<argumets>)
dr.frop(a,b,c,d)
df.drop(2)
df.drop(z,axis=0)
df.drop('city')
df.drop('city',axis=1)

# %%
df.drop('city')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.drop('city')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.drop('city',axis=1)
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
df.drop(2)
# Out:
#     Names  Age city
# 0  Ramesh   20  hyd
# 1  Suresh   22  mum

# %%
df.drop(2,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.drop(2,axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.drop('city',axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.drop('city',axis=1,inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.drop(index=[2])df
#inplace=flase
#iplace=true=overwrite the output in same df
# Out:
#     Names  Age city
# 0  Ramesh   20  hyd
# 1  Suresh   22  mum

# %%
df
# Out:
#      Names  Age  city
# 0   Ramesh   20   hyd
# 1   Suresh   22   mum
# 2  Sathish   24  null

# %%
df.drop('city',axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.drop('city',axis=1,inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %% [markdown]
# **ste-6 rename**

# %%
#df.rename(mapper)
#mapper  means dictionary
c={'Age':'citi'}
df.rename(c,axis=1)
df.rename(columns=c)
# Out:
#     Names  citi
# 0  Ramesh    20
# 1  Suresh    22

# %% [markdown]
# **step-7 save the  data frame**

# %%
- .csv
- .xlsx
- where you  want to save :directory
- on whAT name you want save :names of the file
- on what extension you use :.csv,.xlsx
-diffrent location
- same loation:no need to provie dictectory :'dfls

# %%
df.to_csv(r"C:\Users\Dell\Desktop\files\df1.csv",index=False)

# %%
df.to_excel(r"C:\Users\Dell\Desktop\files\df2.xlsx",index=False)

# %% [markdown]
# **step-8 How to read a Dataframe**

# %%
pd.read_csv(r"C:\Users\Dell\Desktop\files\df1.csv")
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22

# %%
pd.read_excel(r"C:\Users\Dell\Desktop\files\df2.xlsx")
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
