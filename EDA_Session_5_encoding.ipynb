# %%
                                Data read
                                    |
                                Data cleaning
                                    |
                                Data Analysis
                                    |
                                Feature engineering
                                    |
                               Feature Selection
                                    |
                                Model development
                                    |
                                Model evaluation
                                    |
                                Model tuning
                                    |
                                Model deployment

# %% [markdown]
# **Feature Engineering**
#
# - So far we have performed feature analysis
#
#     - Data frame qucik checks
#
#     - Categoroical column analsyis
#
#     - Bar charts , pie charts
#
#     - Numerical column analysis
#
#     - Histograms, box plots , outliers
#
#     - Bi-multi variate analysis
#
#     - correlation etc
#
# - Now we need to learn Feature Engineering
#
#     - we will create a new columns for better ML models
#
#     - we will perform the **Encoding**,which is convert categorical to Numerical data
#
#     - we will do data **transformations**
#
#     - we will perform **Scaling: Standardization and Normalization**
#
#     - we will perform the **missing value analayis**
#
# - Simply feature engineering means our data will be modified

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv(r"C:\Users\Dell\Desktop\files\Visadataset.csv")
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **case_status**

# %%
# first check how many unique lables are there in case_status
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# create a dictinary 
d={'Certified':0,'Denied':1}

# %%
# map the above the dictionary with original column
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df['case_status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
labels=sorted(visa_df['education_of_employee'].unique())
d={j:i for i,j in enumerate(labels)}
visa_df['education_of_employee'].map(d)
# Out:
# 0        2
# 1        3
# 2        0
# 3        0
# 4        3
#         ..
# 25475    0
# 25476    2
# 25477    3
# 25478    3
# 25479    0
# Name: education_of_employee, Length: 25480, dtype: int64

# %%
d
# Out:
# {"Bachelor's": 0, 'Doctorate': 1, 'High School': 2, "Master's": 3}

# %% [markdown]
# - there are two encodings
#
#     - LabelEncoder
#
#     - OrdinalEncoder

# %%
Ramesh  Suresh  Sathish: Nominal data
Red  Green Blue : Nominal data
# Out:
#   Cell In[17], line 1
#     Ramesh  Suresh  Sathish: Nominal data
#             ^
# SyntaxError: invalid syntax

# %%
Education     LabelEncoder   OrdinalEncoder
============================================
HighSchool       1            0

Bachelor         0            1

Masters          2            2

PH.D             3            3


1   0   2  3===> ML model sees this: 3>2>1>0
which indicates : PH.D>Matester>Hschool>Batchelors
# Out:
#   Cell In[18], line 1
#     Education     LabelEncoder   OrdinalEncoder
#                   ^
# SyntaxError: invalid syntax

# %%
# read the data again
visa_df=pd.read_csv(r'C:\Users\omkar\OneDrive\Documents\Gen_AI\Data_files\Visadataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # read the data again
# ----> 2 visa_df=pd.read_csv(r'C:\Users\omkar\OneDrive\Documents\Gen_AI\Data_files\Visadataset.csv')
#
# ...

# %%
- sklearn: **Package**

    - preprocessing: **module**

        - LabelEncoder: **class**

            - fit_transform:**method** 

import sklearn
skleran.preprocessing

from sklearn import preprocessing
dir(preprocessing): LabelEncoder
preprocessing.LabelEncoder

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform()

# Read the class
# save the class
# apply the fit transform
# Out:
#   Cell In[20], line 1
#     - sklearn: **Package**
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform

from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
oe.fit_transform
# Out:
# <bound method TransformerMixin.fit_transform of OrdinalEncoder()>

# %% [markdown]
# **fit transform**
#
# - fit : created a dictionary(find something)
#
# - transform: using above finding we are modify the data
#
#
# from sklearn.module import class
#
# va=class()
#
# va.fit   or va.fit_transform

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **LableEncoder**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
#read the data again
visa_df=pd.read_csv(r"C:\Users\Dell\Desktop\files\Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat[1:]:
    visa_df=le.fit_transform(visa_df[i])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

oe=OrdinalEncoder()
for i in cat[1:]:
    visa_df[i]=oe.fit_transform(visa_df[[i]])

# %%
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01        1.0                    2.0                 0.0
# 1         EZYV02        1.0                    3.0                 1.0
# 2         EZYV03        1.0                    0.0                 0.0
# 3         EZYV04        1.0                    0.0                 0.0
# 4         EZYV05        0.0                    3.0                 1.0
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476        1.0                    0.0                 1.0
# 25476  EZYV25477        1.0                    2.0                 1.0
# 25477  EZYV25478        1.0                    3.0                 1.0
# 25478  EZYV25479        1.0                    3.0                 1.0
# 25479  EZYV25480        1.0                    0.0                 1.0
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\Dell\Desktop\files\Visadataset.csv")

# %% [markdown]
# - get dummies is a way to reprsent the categorical columns to numerical
#
# - first it will  check what are the lables in a columns
# - for example case status has to labels
#      - Denied and certified
# - so it will createtwo new columns based on labels
#     - col1:case_status_Denied
#     - col2: case_sttus_certified
#
#
# case_status| case_status_Denied|case_status_certified
# Denied     |          1       |          0
# certified  |          0       |          1
# certified  |          0       |          1
#
# **it is also called as one hot encoder**
# - it makes new columns are independent each other
# - some of ml alorithms expect that columns sholud be independent each other

# %%
pd.get_dummies(visa_df['case_status'],dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]
